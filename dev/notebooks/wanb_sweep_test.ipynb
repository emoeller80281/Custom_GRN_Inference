# %%
# !wandb agent luminarada-penn-state-health/multiomic_transformer/7w8w2ar7
# Out:
# wandb: Starting wandb agent 🕵️
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /gpfs/Home/esm5360/.netrc.
# 2026-05-04 17:51:24,184 - wandb.wandb_agent - INFO - Running runs: []
# 2026-05-04 17:51:24,990 - wandb.wandb_agent - INFO - Agent received command: run
# 2026-05-04 17:51:24,990 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	bias_scale: 3
# 	d_ff: 425
# 	d_model: 284
# 	dropout: 0.04333500017508398
# 	kernel_size: 118
# 	model: MultiomicTransformer
# 	num_heads: 10
# 	num_layers: 7
# 	use_dist_bias: true
# 2026-05-04 17:51:24,992 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python /gpfs/Labs/Uzun/SCRIPTS/PROJECTS/2024.SINGLE_CELL_GRN_INFERENCE.MOELLER/dev/wandb_train.py --bias_scale=3 --d_ff=425 --d_model=284 --dropout=0.04333500017508398 --kernel_size=118 --model=MultiomicTransformer --num_heads=10 --num_layers=7 --use_dist_bias=true
# 2026-05-04 17:51:30,002 - wandb.wandb_agent - INFO - Running runs: ['w1rsi9c3']
# ...
